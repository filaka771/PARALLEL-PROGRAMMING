    3000010: 0.357931,
    4000010: 0.513788,
    5000010: 0.612136,
    6000010: 0.753256,
    7000010: 0.891437,
    8000010: 1.00878,
    9000010: 1.13627,
    10000010: 1.30405,
    11000010: 1.399,
    12000010: 1.53799,
    13000010: 1.65296,
    14000010: 1.80892,
    15000010: 1.91877,
    16000010: 2.11535,
    17000010: 2.24269,
    18000010: 2.40076,
    19000010: 2.54988,
    20000010: 2.63394,
    21000010: 2.76893,
    22000010: 2.90283,
    23000010: 2.9842,
    24000010: 3.25162,
    25000010: 3.30054,
    26000010: 3.44905,
    27000010: 3.61974,
    28000010: 3.81209,
    29000010: 3.89774,
    30000010: 4.0133,
    31000010: 4.24307,
    32000010: 4.45284,
    33000010: 4.48034,
    34000010: 4.76259,
    35000010: 4.71513,
    36000010: 4.82553,
    37000010: 5.0294,
    38000010: 5.13322,
    39000010: 5.43773,
    40000010: 5.34859,
    41000010: 5.54218,
    42000010: 5.74904,
    43000010: 5.82442,
    44000010: 5.9227,
    45000010: 6.20324,
    46000010: 6.32727,
    47000010: 6.5306,
    48000010: 6.52819,
    49000010: 6.82442
  }
}

# %%
x = data[1].keys()

t1 = data[1].values()
t2 = data[2].values()
t4 = data[4].values()

# %%
s2 = [v1 / v2 for v1, v2 in zip(t1, t2)]
s4 = [v1 / v4 for v1, v4 in zip(t1, t4)]

e2 = [v / 2 for v in s2]
e4 = [v / 4 for v in s4]

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость ускорения от размера массива при n = 2")
plt.plot(x, s2)
plt.xlabel("Array size")
plt.ylabel("S")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость ускорения от размера массива при n = 4")
plt.plot(x, s4)
plt.xlabel("Array size")
plt.ylabel("S")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость эффективности от размера массива при n = 2")
plt.plot(x, e2)
plt.xlabel("Array size")
plt.ylabel("E")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость эффективности от размера массива при n = 4")
plt.plot(x, e4)
plt.xlabel("Array size")
plt.ylabel("E")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость времени сортировки от размера массива при n = 2")
plt.plot(x, t2)
plt.xlabel("Array size")
plt.ylabel("T")
plt.grid()
plt.show()

# %%
plt.figure(figsize=[18, 10])
plt.title("Зависимость времени сортировки от размера массива при n = 4")
plt.plot(x, t4)
plt.xlabel("Array size")
plt.ylabel("T")
plt.grid()
plt.show()
